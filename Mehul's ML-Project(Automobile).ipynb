# %% [markdown]
# # IMPORTING RELEVANT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading CSV File

# %%
data = pd.DataFrame(pd.read_csv("F:/ML Project1/ML Project 2_ Automobile/automobile.csv"))

# %%
data.head()
# Out:
#    symboling                      make fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
data.shape
# Out:
# (205, 25)

# %%
data.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   make              205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
#cleaning the data

# %%
data.isnull().sum()*100/data.shape[0]
# Out:
# symboling           0.0
# make                0.0
# fueltype            0.0
# aspiration          0.0
# doornumber          0.0
# carbody             0.0
# drivewheel          0.0
# enginelocation      0.0
# wheelbase           0.0
# carlength           0.0
# carwidth            0.0
# carheight           0.0
# curbweight          0.0
# enginetype          0.0
# cylindernumber      0.0
# enginesize          0.0
# fuelsystem          0.0
# boreratio           0.0
# stroke              0.0
# compressionratio    0.0
# horsepower          0.0
# peakrpm             0.0
# citympg             0.0
# highwaympg          0.0
# price               0.0
# dtype: float64

# %%
#no null values

# %% [markdown]
# # Perform EDA on the data

# %%
#univariate analysing the target variable price

# %% [markdown]
# # price
#
# data.price.describe()

# %%
sns.distplot(data['price'])

# %%
#mean and median of price are different
#most of the car prices are in range from 8000-9000

# %% [markdown]
# # symboling

# %%
#Cars are initially assigned a risk factor symbol associated with its price. Then, if it is more risky (or less),
#this symbol is adjusted by moving it up (or down) the scale. Actuarians call this process "symboling". A
#value of +3 indicates that the auto is risky 
#-3 that it is probably pretty safe

# %%
plot1 = sns.countplot(data['symboling'])
plot1.set(xlabel = 'Symbol', ylabel= 'Count of Cars')
plt.show()
plt.tight_layout()

# %%
#price of cars in each symbol category

# %%
plot1 = data[['symboling','price']].groupby("symboling").mean().plot(kind='bar',legend = False,)
plot1.set_xlabel("Symbol")
plot1.set_ylabel("Avg Price (Dollars)")
xticks(rotation = 0)
plt.show()

# %%
#by this we can understyand that:
# symbol 0 or 1 have more than 50% car
# Average price of car is lower for 0,1,2 in symbol category.

# %% [markdown]
# # make

# %%
data.make.values[0:10]
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 100ls', 'audi 5000', 'audi 4000',
#        'audi 5000s (diesel)'], dtype=object)

# %%
#from above we can understand that there are 2 name for car make ie the company name and the model name
#lets split car company to a newcolumn

# %%
data['carbrand'] = data.make.str.split(' ').str.get(0).str.upper()

# %%
len(set(data.carbrand.values))
# Out:
# 27

# %%
plot = plt.subplots(figsize = (15,5))
plot1 = sns.countplot(data['carbrand'], order=pd.value_counts(data['carbrand']).index,)
plot1.set(xlabel = 'Brand', ylabel= 'Count of Cars')
xticks(rotation = 90)
plt.show()
plt.tight_layout()

# %%
#while observing the above plot we can see little bit of spelling errors in names 

data['carbrand'] = data['carbrand'].replace(['VW', 'VOKSWAGEN'], 'VOLKSWAGEN')
data['carbrand'] = data['carbrand'].replace(['MAXDA'], 'MAZDA')
data['carbrand'] = data['carbrand'].replace(['PORCSHCE'], 'PORSCHE')
data['carbrand'] = data['carbrand'].replace(['TOYOUTA'], 'TOYOTA')

# %%
plot = plt.subplots(figsize = (15,5))
plot1 = sns.countplot(data['carbrand'], order=pd.value_counts(data['carbrand']).index,)
plot1.set(xlabel = 'Brand', ylabel= 'Count of Cars')
xticks(rotation = 90)
plt.show()
plt.tight_layout()

# %%
data.carbrand.describe()
# Out:
# count        205
# unique        22
# top       TOYOTA
# freq          32
# Name: carbrand, dtype: object

# %%
#average car price of each company

# %%
avg_price = data[['carbrand','price']].groupby("carbrand", as_index = False).mean().rename(columns={'price':'brand_avg_price'})
plt1 = avg_price.plot(x = 'carbrand', kind='bar',legend = False, sort_columns = True, figsize = (15,3))
plt1.set_xlabel("Brand")
plt1.set_ylabel("Avg Price (Dollars)")
xticks(rotation = 90)
plt.show()

# %%
data = data.merge(avg_price, on = 'carbrand')

# %%
data['brand_category'] = data['brand_avg_price'].apply(lambda x : "Budget" if x < 10000 
                                                     else ("Mid_Range" if 10000 <= x < 20000
                                                           else "Luxury"))

# %% [markdown]
# # fueltype

# %%
fuel_avg_price = data[['fueltype','price']].groupby("fueltype", as_index = False).mean().rename(columns={'price':'fuel_avg_price'})
plt1 = fuel_avg_price.plot(x = 'fueltype', kind='bar',legend = False, sort_columns = True)
plt1.set_xlabel("Fuel Type")
plt1.set_ylabel("Avg Price ")
xticks(rotation = 0)
plt.show()

# %%
#diesel cars are more priced than gas cars

# %% [markdown]
# # aspiration

# %%
asp_avg_price = data[['aspiration','price']].groupby("aspiration", as_index = False).mean().rename(columns={'price':'asp_avg_price'})
plt1 = asp_avg_price.plot(x = 'aspiration', kind='bar',legend = False, sort_columns = True)
plt1.set_xlabel("Aspiration")
plt1.set_ylabel("Avg Price ")
xticks(rotation = 0)
plt.show()

# %%
#cars with high turbo power is highly priced

# %% [markdown]
# # doornumber

# %%
door_avg_price = data[['doornumber','price']].groupby("doornumber", as_index = False).mean().rename(columns={'price':'door_avg_price'})
plt1 = door_avg_price.plot(x = 'doornumber', kind='bar',legend = False, sort_columns = True)
plt1.set_xlabel("No of Doors")
plt1.set_ylabel("Avg Price")
xticks(rotation = 0)
plt.show()

# %%
#number of doors have no effect on the price of cars

# %% [markdown]
# # carbody

# %%
carbody_avg_price = data[['carbody','price']].groupby("carbody", as_index = False).mean().rename(columns={'price':'carbody_avg_price'})
plt1 = carbody_avg_price.plot(x = 'carbody', kind='bar',legend = False, sort_columns = True)
plt1.set_xlabel("Car Body")
plt1.set_ylabel("Avg Price")
xticks(rotation = 0)
plt.show()

# %%
#convertible and hardtop are high priced whereas hatchback and wagon are low priced

# %%
drivewheel_avg_price = data[['drivewheel','price']].groupby("drivewheel", as_index = False).mean().rename(columns={'price':'drivewheel_avg_price'})
plt1 = drivewheel_avg_price.plot(x = 'drivewheel', kind='bar', sort_columns = True,legend = False,)
plt1.set_xlabel("Drive Wheel Type")
plt1.set_ylabel("Avg Price ")
xticks(rotation = 0)
plt.show()

# %%
#rear wheel drive cars are highly priced cars

# %% [markdown]
# # wheelbase

# %%
plt1 = sns.scatterplot(x = 'wheelbase', y = 'price', data = data)
plt1.set_xlabel('Wheelbase ')
plt1.set_ylabel('Price of Car')
plt.show()

# %%
#most of the cars wheelbase is in 95 inches and they are positively corelated with wheelbase

# %% [markdown]
# # Engine specification(engine type,cylinder, fuel system)

# %%
plot, axs = plt.subplots(1,3,figsize=(20,5))

engine_avg_price = data[['enginetype','price']].groupby("enginetype", as_index = False).mean().rename(columns={'price':'engine_avg_price'})
plt1 = engine_avg_price.plot(x = 'enginetype', kind='bar', sort_columns = True, legend = False, ax = axs[0])
plt1.set_xlabel("Engine Type")
plt1.set_ylabel("Avg Price ")
xticks(rotation = 0)

cylindernumber_avg_price = data[['cylindernumber','price']].groupby("cylindernumber", as_index = False).mean().rename(columns={'price':'cylindernumber_avg_price'})
plt1 = cylindernumber_avg_price.plot(x = 'cylindernumber', kind='bar', sort_columns = True,legend = False, ax = axs[1])
plt1.set_xlabel("Cylinder Number")
plt1.set_ylabel("Avg Price ")
xticks(rotation = 0)

fuelsystem_avg_price = data[['fuelsystem','price']].groupby("fuelsystem", as_index = False).mean().rename(columns={'price':'fuelsystem_avg_price'})
plt1 = fuelsystem_avg_price.plot(x = 'fuelsystem', kind='bar', sort_columns = True,legend = False, ax = axs[2])
plt1.set_xlabel("Fuel System")
plt1.set_ylabel("Avg Price ")
xticks(rotation = 0)
plt.show()

# %%
#dohcv and ohcv engine types are priced high.
# Eight and twelve cylinder cars have higher price.
# IDI and MPFI fuel system have higher price.

# %% [markdown]
# # dimensions of the car,(hieght,weight,length,width)

# %%
plot, axs = plt.subplots(2,2,figsize=(15,10))
plt1 = sns.scatterplot(x = 'carlength', y = 'price', data = data, ax = axs[0,0])
plt1.set_xlabel('Length of Car ')
plt1.set_ylabel('Price of Car ')
plt2 = sns.scatterplot(x = 'carwidth', y = 'price', data = data, ax = axs[0,1])
plt2.set_xlabel('Width of Car ')
plt2.set_ylabel('Price of Car ')
plt3 = sns.scatterplot(x = 'carheight', y = 'price', data = data, ax = axs[1,0])
plt3.set_xlabel('Height of Car ')
plt3.set_ylabel('Price of Car ')
plt3 = sns.scatterplot(x = 'curbweight', y = 'price', data = data, ax = axs[1,1])
plt3.set_xlabel('Weight of Car')
plt3.set_ylabel('Price of Car')
plt.tight_layout()

# %%
#Length,width and weight of the car is positively corelated with the price.
# only slight correlation with Height of the car with price.

# %% [markdown]
# # Engine Size, Stroke,Bore Ratio, Horsepower & Compression Ratio

# %%
plot, axs = plt.subplots(3,2,figsize=(20,20))

plt1 = sns.scatterplot(x = 'enginesize', y = 'price', data = data, ax = axs[0,0])
plt1.set_xlabel('Size of Engine (Cubic Inches)')
plt1.set_ylabel('Price of Car ')

plt2 = sns.scatterplot(x = 'boreratio', y = 'price', data = data, ax = axs[0,1])
plt2.set_xlabel('Bore Ratio')
plt2.set_ylabel('Price of Car ')

plt3 = sns.scatterplot(x = 'stroke', y = 'price', data = data, ax = axs[1,0])
plt3.set_xlabel('Stroke')
plt3.set_ylabel('Price of Car')

plt4 = sns.scatterplot(x = 'compressionratio', y = 'price', data = data, ax = axs[1,1])
plt4.set_xlabel('Compression Ratio')
plt4.set_ylabel('Price of Car ')

plt5 = sns.scatterplot(x = 'horsepower', y = 'price', data = data, ax = axs[2,0])
plt5.set_xlabel('Horsepower')
plt5.set_ylabel('Price of Car')

plt5 = sns.scatterplot(x = 'peakrpm', y = 'price', data = data, ax = axs[2,1])
plt5.set_xlabel('Peak RPM')
plt5.set_ylabel('Price of Car')
plt.tight_layout()
plt.show()

# %%
#size of engine, bore ratio, and horsepower has positive correlation with price.

# %% [markdown]
# # City Mileage and Highway Mileage

# %%
data['mileage'] = data['citympg']*0.55 + data['highwaympg']*0.45

# %%
plt1 = sns.scatterplot(x = 'mileage', y = 'price', data = data)
plt1.set_xlabel('Mileage')
plt1.set_ylabel('Price of Car (Dollars)')
plt.show()

# %%
#negative corelation with price

# %%
#lets do a bivariate analysis

# %% [markdown]
# # brand and milege

# %%
plt1 = sns.scatterplot(x = 'mileage', y = 'price', hue = 'brand_category', data = data)
plt1.set_xlabel('Mileage')
plt1.set_ylabel('Price of Car')
plt.show()

# %% [markdown]
# # brand and horsepower

# %%
plt1 = sns.scatterplot(x = 'horsepower', y = 'price', hue = 'brand_category', data = data)
plt1.set_xlabel('Horsepower')
plt1.set_ylabel('Price of Car ')
plt.show()

# %% [markdown]
# # horsepower and fuel type

# %%
plt1 = sns.scatterplot(x = 'horsepower', y = 'price', hue = 'fueltype', data = data)
plt1.set_xlabel('Horsepower')
plt1.set_ylabel('Price of Car')
plt.show()

# %% [markdown]
# # mileage and fuel type

# %%
plt1 = sns.scatterplot(x = 'mileage', y = 'price', hue = 'fueltype', data = data)
plt1.set_xlabel('Mileage')
plt1.set_ylabel('Price of Car')
plt.show()

# %%
# from above eda analysis we can say that the features affecting the price are these
#Brand Category,Fuel Type,Aspiration,Car Body,Drive Wheel,Wheelbase
#,Car Length,Car Width,Curb weight,Engine Type,Cylinder Number
#,Engine Size,Bore Ratio,Horsepower,Mileage

# %% [markdown]
# # Linear rergression model

# %%
Lrmodel = data[['cylindernumber', 'enginesize',  'boreratio', 'horsepower','price', 'brand_category', 'mileage','fueltype',
                'aspiration', 'carbody', 'drivewheel', 'wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginetype']]

# %%
Lrmodel.head()
# Out:
#   cylindernumber  enginesize  boreratio  horsepower    price brand_category  \
# 0           four         130       3.47         111  13495.0      Mid_Range
# 1           four         130       3.47         111  16500.0      Mid_Range
# 2            six         152       2.68         154  16500.0      Mid_Range
# 3           four         109       3.19         102  13950.0      Mid_Range
# 4           five         136       3.19         115  17450.0      Mid_Range
#
#    mileage fueltype aspiration      carbody drivewheel  wheelbase  carlength  \
# 0    23.70      gas        std  convertible        rwd       88.6      168.8
# 1    23.70      gas        std  convertible        rwd       88.6      168.8
# 2    22.15      gas        std    hatchback        rwd       94.5      171.2
# 3    26.70      gas        std        sedan        fwd       99.8      176.6
# 4    19.80      gas        std        sedan        4wd       99.4      176.6
#
#    carwidth  curbweight enginetype
# ...

# %%
#pairplot for all numarical variables

# %%
plt.figure(figsize = (16,16))
sns.pairplot(Lrmodel)
plt.show()

# %%
plt.figure(figsize=(10, 20))
plt.subplot(4,2,1)
sns.boxplot(x = 'fueltype', y = 'price', data = Lrmodel)
plt.subplot(4,2,2)
sns.boxplot(x = 'aspiration', y = 'price', data = Lrmodel)
plt.subplot(4,2,3)
sns.boxplot(x = 'carbody', y = 'price', data = Lrmodel)
plt.subplot(4,2,4)
sns.boxplot(x = 'drivewheel', y = 'price', data = Lrmodel)
plt.subplot(4,2,5)
sns.boxplot(x = 'enginetype', y = 'price', data = Lrmodel)
plt.subplot(4,2,6)
sns.boxplot(x = 'brand_category', y = 'price', data = Lrmodel)
plt.subplot(4,2,7)
sns.boxplot(x = 'cylindernumber', y = 'price', data = Lrmodel)
plt.tight_layout()
plt.show()

# %%
#converting categorical variable into numerical variable

# %%
cylno = pd.get_dummies(Lrmodel['cylindernumber'], drop_first = True)

Lrmodel = pd.concat([Lrmodel, cylno], axis = 1)

brand_cat = pd.get_dummies(Lrmodel['brand_category'], drop_first = True)

Lrmodel = pd.concat([Lrmodel, brand_cat], axis = 1)

eng_typ = pd.get_dummies(Lrmodel['enginetype'], drop_first = True)

Lrmodel = pd.concat([Lrmodel, eng_typ], axis = 1)

drwh = pd.get_dummies(Lrmodel['drivewheel'], drop_first = True)

Lrmodel = pd.concat([Lrmodel, drwh], axis = 1)

carbo = pd.get_dummies(Lrmodel['carbody'], drop_first = True)

Lrmodel = pd.concat([Lrmodel, carbo], axis = 1)

aspir = pd.get_dummies(Lrmodel['aspiration'], drop_first = True)

Lrmodel = pd.concat([Lrmodel, aspir], axis = 1)

fuelty = pd.get_dummies(Lrmodel['fueltype'], drop_first = True)

Lrmodel = pd.concat([Lrmodel, fuelty], axis = 1)

Lrmodel.drop(['fueltype', 'aspiration', 'carbody', 'drivewheel', 'enginetype', 'cylindernumber','brand_category'], axis = 1, inplace = True)

# %% [markdown]
# # Splitting the Data into Training and Testing sets

# %%
from sklearn.model_selection import train_test_split

np.random.seed(0)

df_train, df_test = train_test_split(Lrmodel, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
num_vars = ['enginesize','boreratio', 'horsepower', 'price','mileage','wheelbase', 'carlength', 'carwidth', 'curbweight']

df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#      enginesize  boreratio  horsepower     price   mileage  wheelbase  \
# 122    0.139623   0.230159    0.083333  0.068818  0.530864   0.244828
# 125    0.339623   1.000000    0.395833  0.466890  0.213992   0.272414
# 166    0.139623   0.444444    0.266667  0.122110  0.344307   0.272414
# 1      0.260377   0.626984    0.262500  0.314446  0.244170   0.068966
# 199    0.260377   0.746032    0.475000  0.382131  0.122085   0.610345
#
#      carlength  carwidth  curbweight  five  ...  ohcv  rotor  fwd  rwd  \
# 122   0.426016  0.291667    0.272692     0  ...     0      0    1    0
# 125   0.452033  0.666667    0.500388     0  ...     0      0    0    1
# 166   0.448780  0.308333    0.314973     0  ...     0      0    0    1
# 1     0.450407  0.316667    0.411171     0  ...     0      0    0    1
# 199   0.775610  0.575000    0.647401     0  ...     0      0    0    1
#
#      hardtop  hatchback  sedan  wagon  turbo  gas
# 122        0          0      1      0      0    1
# ...

# %%
df_train.describe()
# Out:
#        enginesize   boreratio  horsepower       price     mileage   wheelbase  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  143.000000
# mean     0.241351    0.497946    0.227302    0.219310    0.358265    0.411141
# std      0.154619    0.207140    0.165511    0.215682    0.185980    0.205581
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.135849    0.305556    0.091667    0.067298    0.198903    0.272414
# 50%      0.184906    0.500000    0.191667    0.140343    0.344307    0.341379
# 75%      0.301887    0.682540    0.283333    0.313479    0.512346    0.503448
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         carlength    carwidth  curbweight        five  ...        ohcv  \
# count  143.000000  143.000000  143.000000  143.000000  ...  143.000000
# mean     0.525476    0.461655    0.407878    0.062937  ...    0.062937
# ...

# %%
#correlation

plt.figure(figsize = (16, 10))
sns.heatmap(df_train.corr(), annot = True)
plt.show()

# %%
#getting the x,y train set for model building

# %%
X_train = df_train
y_train = df_train.pop('price')

# %%
#recursive feature elimination

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, 10)       
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('enginesize', False, 13),
#  ('boreratio', False, 10),
#  ('horsepower', True, 1),
#  ('mileage', True, 1),
#  ('wheelbase', False, 3),
#  ('carlength', False, 11),
#  ('carwidth', True, 1),
#  ('curbweight', True, 1),
#  ('five', False, 6),
#  ('four', False, 4),
#  ('six', False, 5),
#  ('three', False, 14),
#  ('twelve', True, 1),
#  ('two', False, 20),
#  ('Luxury', True, 1),
#  ('Mid_Range', False, 12),
#  ('dohcv', True, 1),
#  ('l', False, 19),
#  ('ohc', False, 7),
#  ('ohcf', False, 8),
#  ('ohcv', False, 9),
#  ('rotor', False, 21),
#  ('fwd', False, 16),
#  ('rwd', False, 15),
#  ('hardtop', False, 2),
#  ('hatchback', True, 1),
#  ('sedan', True, 1),
#  ('wagon', True, 1),
#  ('turbo', False, 18),
#  ('gas', False, 17)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['horsepower', 'mileage', 'carwidth', 'curbweight', 'twelve', 'Luxury',
#        'dohcv', 'hatchback', 'sedan', 'wagon'],
#       dtype='object')

# %%
#Building model using statsmodel

# %%
X_train_rfe = X_train[col]

# %%
import statsmodels.api as sm  
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
lm = sm.OLS(y_train,X_train_rfe).fit()

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.929
# Model:                            OLS   Adj. R-squared:                  0.923
# Method:                 Least Squares   F-statistic:                     172.1
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           1.29e-70
# Time:                        21:29:13   Log-Likelihood:                 205.85
# No. Observations:                 143   AIC:                            -389.7
# Df Residuals:                     132   BIC:                            -357.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0947      0.042     -2.243      0.027      -0.178      -0.011
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_rfe
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#       Features    VIF
# 0        const  71.51
# 4   curbweight   8.38
# 9        sedan   6.18
# 1   horsepower   5.94
# 8    hatchback   5.68
# 3     carwidth   5.19
# 2      mileage   3.74
# 10       wagon   3.62
# 7        dohcv   1.73
# 6       Luxury   1.68
# 5       twelve   1.27

# %%
X_train_new1 = X_train_rfe.drop(["twelve"], axis = 1)


# Adding a constant variable 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new1)

lm = sm.OLS(y_train,X_train_lm).fit()  

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.927
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     187.9
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           4.25e-71
# Time:                        21:44:45   Log-Likelihood:                 204.17
# No. Observations:                 143   AIC:                            -388.3
# Df Residuals:                     133   BIC:                            -358.7
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0764      0.041     -1.851      0.066      -0.158       0.005
# ...

# %%
X_train_new2 = X_train_new1.drop(["mileage"], axis = 1)

import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new2)

lm = sm.OLS(y_train,X_train_lm).fit()  

print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.926
# Model:                            OLS   Adj. R-squared:                  0.922
# Method:                 Least Squares   F-statistic:                     209.5
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           7.86e-72
# Time:                        21:45:00   Log-Likelihood:                 203.07
# No. Observations:                 143   AIC:                            -388.1
# Df Residuals:                     134   BIC:                            -361.5
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0305      0.026     -1.165      0.246      -0.082       0.021
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new2
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 0       const  26.90
# 3  curbweight   8.10
# 7       sedan   6.07
# 6   hatchback   5.63
# 2    carwidth   5.14
# 1  horsepower   3.61
# 8       wagon   3.58
# 4      Luxury   1.63
# 5       dohcv   1.46

# %%
X_train_new3 = X_train_new2.drop(["curbweight"], axis = 1)
 
import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new3)

lm = sm.OLS(y_train,X_train_lm).fit()  

print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                     215.9
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           4.70e-70
# Time:                        21:45:27   Log-Likelihood:                 195.77
# No. Observations:                 143   AIC:                            -375.5
# Df Residuals:                     135   BIC:                            -351.8
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0319      0.027     -1.161      0.248      -0.086       0.022
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new3
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 0       const  26.89
# 6       sedan   6.06
# 5   hatchback   5.54
# 7       wagon   3.47
# 1  horsepower   2.50
# 2    carwidth   2.22
# 3      Luxury   1.56
# 4       dohcv   1.21

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new3
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 0       const  26.89
# 6       sedan   6.06
# 5   hatchback   5.54
# 7       wagon   3.47
# 1  horsepower   2.50
# 2    carwidth   2.22
# 3      Luxury   1.56
# 4       dohcv   1.21

# %%
X_train_new4 = X_train_new3.drop(["sedan"], axis = 1)


import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new4)

lm = sm.OLS(y_train,X_train_lm).fit() 

print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     237.6
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           1.68e-69
# Time:                        21:57:10   Log-Likelihood:                 191.46
# No. Observations:                 143   AIC:                            -368.9
# Df Residuals:                     136   BIC:                            -348.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0934      0.018     -5.219      0.000      -0.129      -0.058
# ...

# %%
# Dropping wagon as p value is high.
X_train_new5 = X_train_new4.drop(["wagon"], axis = 1)

import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new5)

lm = sm.OLS(y_train,X_train_lm).fit()  

print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     284.8
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           1.57e-70
# Time:                        21:57:30   Log-Likelihood:                 190.93
# No. Observations:                 143   AIC:                            -369.9
# Df Residuals:                     137   BIC:                            -352.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0970      0.018     -5.530      0.000      -0.132      -0.062
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
X = X_train_new5
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#      Features    VIF
# 0       const  10.39
# 1  horsepower   2.39
# 2    carwidth   2.08
# 3      Luxury   1.53
# 4       dohcv   1.21
# 5   hatchback   1.13

# %%
X_train_new6 = X_train_new5.drop(["dohcv"], axis = 1)


import statsmodels.api as sm  
X_train_lm = sm.add_constant(X_train_new6)

lm = sm.OLS(y_train,X_train_lm).fit()  

print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     308.0
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           1.04e-67
# Time:                        21:57:58   Log-Likelihood:                 181.06
# No. Observations:                 143   AIC:                            -352.1
# Df Residuals:                     138   BIC:                            -337.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0824      0.018     -4.480      0.000      -0.119      -0.046
# ...

# %%
#lets plot the histogram of the error terms

# %%
y_train_price = lm.predict(X_train_lm)

# %%
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)   
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %%
#appliying scaling on test sets

# %%
num_vars = ['wheelbase', 'carlength', 'carwidth', 'curbweight', 'enginesize','boreratio', 'horsepower', 'price','mileage']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
y_test = df_test.pop('price')
X_test = df_test

# %%
X_test_new = X_test[['carwidth', 'horsepower', 'Luxury', 'hatchback']]

X_test_new = sm.add_constant(X_test_new)

# %%
y_pred = lm.predict(X_test_new)

# %%
#evaluating the model

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_pred)
# Out:
# -2.690176124875176

# %%
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.899
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     308.0
# Date:                Thu, 17 Dec 2020   Prob (F-statistic):           1.04e-67
# Time:                        22:03:05   Log-Likelihood:                 181.06
# No. Observations:                 143   AIC:                            -352.1
# Df Residuals:                     138   BIC:                            -337.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0824      0.018     -4.480      0.000      -0.119      -0.046
# ...

# %% [markdown]
# #   The main Factors that drive price are-
#
#     Engine size and Horse Power
#     Stroke
#     Compression Ratio
#     Peak rpm
#     BRAND
